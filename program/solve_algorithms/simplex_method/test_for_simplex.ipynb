# %%
import numpy as np

# %%
from simplex_method import SimplexMethod

# %%
material_tables = [
    [
        [2, 4],
        [1, 1],
        [2, 1]
    ],
    [
        [2, 4, 5],
        [1, 8, 6],
        [7, 4, 5],
        [4, 6 ,7]
    ],
    [
        [0.8, 0.5, 1, 2, 1.1],
        [0.2, 0.1, 0.1, 0.1, 0.2],
        [0.3, 0.4, 0.6, 1.3, 0.05],
        [0.2, 0.3, 0.3, 0.7, 0.5],
        [0.7, 0.1, 0.9, 1.5, 0]
    ],
    [
        [0.1, 0.4],
        [0.01, 0.04]
    ],
    [
        [3, 2],
        [2, 5]
    ]
]

reserves = [
    [560, 170, 300],
    [120, 280, 240, 360],
    [1411, 149, 815.5, 466, 1080],
    [160, 24],
    [18, 20]
]

profits = [
    [4, 5],
    [10, 14, 12],
    [1, 0.7, 1, 2, 0.6],
    [1, 3],
    [-2, -3]
]

# %%
task_index = 2
method = SimplexMethod(material_tables[task_index], 
                        reserves[task_index], 
                        profits[task_index]
                        )
for item in method.solution.items():
    print(item)
# Out:
# ('iterations', [{'simplex_table': [[0.8, 0.5, 1, 2, 1.1, 1, 0, 0, 0, 0], [0.2, 0.1, 0.1, 0.1, 0.2, 0, 1, 0, 0, 0], [0.3, 0.4, 0.6, 1.3, 0.05, 0, 0, 1, 0, 0], [0.2, 0.3, 0.3, 0.7, 0.5, 0, 0, 0, 1, 0], [0.7, 0.1, 0.9, 1.5, 0, 0, 0, 0, 0, 1]], 'basis': [5, 6, 7, 8, 9], 'deltas': [-1.0, -0.7, -1.0, -2.0, -0.6, 0, 0, 0, 0, 0], 'reserves': [1411, 149, 815.5, 466, 1080], 'function': 0.0, 'profits': [1, 0.7, 1, 2, 0.6, 0, 0, 0, 0, 0]}, {'simplex_table': [[0.33846153846153854, -0.11538461538461542, 0.07692307692307698, 0.0, 1.0230769230769232, 1.0, 0.0, -1.5384615384615383, 0.0, 0.0], [0.17692307692307693, 0.06923076923076923, 0.05384615384615385, 0.0, 0.19615384615384618, 0.0, 1.0, -0.07692307692307693, 0.0, 0.0], [0.23076923076923075, 0.3076923076923077, 0.4615384615384615, 1.0, 0.038461538461538464, 0.0, 0.0, 0.7692307692307692, 0.0, 0.0], [0.03846153846153849, 0.08461538461538459, -0.02307692307692305, 0.0, 0.47307692307692306, 0.0, 0.0, -0.5384615384615383, 1.0, 0.0], [0.3538461538461538, -0.3615384615384616, 0.20769230769230773, 0.0, -0.057692307692307696, 0.0, 0.0, -1.1538461538461537, 0.0, 1.0]], 'basis': [5, 6, 3, 8, 9], 'deltas': [-0.5384615384615385, -0.08461538461538454, -0.07692307692307698, 0.0, -0.523076923076923, 0.0, 0.0, 1.5384615384615383, 0.0, 0.0], 'reserves': [156.38461538461547, 86.26923076923077, 627.3076923076923, 26.884615384615415, 139.03846153846166], 'function': 1254.6153846153845, 'profits': [1, 0.7, 1, 2, 0.6, 0, 0, 0, 0, 0]}, {'simplex_table': [[0.0, 0.23043478260869582, -0.12173913043478266, 0.0, 1.0782608695652176, 1.0, 0.0, -0.4347826086956519, 0.0, -0.956521739130435], [0.0, 0.2500000000000001, -0.05000000000000003, 0.0, 0.22500000000000003, 0.0, 1.0, 0.49999999999999994, 0.0, -0.5], [0.0, 0.5434782608695653, 0.3260869565217391, 1.0, 0.07608695652173914, 0.0, 0.0, 1.5217391304347825, 0.0, -0.6521739130434783], [0.0, 0.12391304347826089, -0.04565217391304348, 0.0, 0.47934782608695653, 0.0, 0.0, -0.41304347826086935, 1.0, -0.10869565217391314], [1.0, -1.021739130434783, 0.5869565217391306, 0.0, -0.1630434782608696, 0.0, 0.0, -3.260869565217391, 0.0, 2.8260869565217392]], 'basis': [5, 6, 3, 8, 0], 'deltas': [0.0, -0.6347826086956523, 0.23913043478260887, 0.0, -0.6108695652173913, 0.0, 0.0, -0.21739130434782616, 0.0, 1.5217391304347827], 'reserves': [23.391304347826008, 16.74999999999993, 536.6304347826085, 11.771739130434787, 392.934782608696], 'function': 1466.195652173913, 'profits': [1, 0.7, 1, 2, 0.6, 0, 0, 0, 0, 0]}, {'simplex_table': [[0.0, 0.0, -0.07565217391304349, 0.0, 0.8708695652173915, 1.0, -0.9217391304347828, -0.8956521739130432, 0.0, -0.4956521739130436], [0.0, 1.0, -0.20000000000000004, 0.0, 0.8999999999999997, 0.0, 3.9999999999999982, 1.999999999999999, 0.0, -1.9999999999999991], [0.0, 0.0, 0.43478260869565216, 1.0, -0.41304347826086946, 0.0, -2.1739130434782603, 0.43478260869565255, 0.0, 0.4347826086956519], [0.0, 0.0, -0.020869565217391296, 0.0, 0.36782608695652175, 0.0, -0.49565217391304334, -0.660869565217391, 1.0, 0.13913043478260853], [1.0, 0.0, 0.382608695652174, 0.0, 0.7565217391304347, 0.0, 4.08695652173913, -1.2173913043478266, 0.0, 0.7826086956521743]], 'basis': [5, 1, 3, 8, 0], 'deltas': [0.0, 0.0, 0.11217391304347823, 0.0, -0.039565217391304364, 0.0, 2.539130434782608, 1.0521739130434775, 0.0, 0.2521739130434788], 'reserves': [7.95217391304346, 66.99999999999969, 500.2173913043478, 3.469565217391345, 461.3913043478262], 'function': 1508.7260869565216, 'profits': [1, 0.7, 1, 2, 0.6, 0, 0, 0, 0, 0]}, {'simplex_table': [[0.0, 0.0, -0.08686969545681478, 0.0, 1.0, 1.148277583624563, -1.0584123814278583, -1.0284573140289561, 0.0, -0.5691462805791314], [0.0, 1.0, -0.12181727408886676, 0.0, 0.0, -1.0334498252621063, 4.952571143285071, 2.9256115826260594, 0.0, -1.487768347478781], [0.0, 0.0, 0.39890164752870694, 1.0, 0.0, 0.47428856714927586, -2.611083374937593, 0.00998502246630123, 0.0, 0.19970044932601072], [0.0, 0.0, 0.011083374937593617, 0.0, 0.0, -0.42236645032451314, -0.106340 ...
# ('parameters', {0: 454.48327508736907, 1: 58.78182725911104, 3: 503.98901647528703, 4: 9.13130304543183})
# ('function', 1509.08736894658)

# %%
SimplexMethod.__dict__
# Out:
# mappingproxy({'__module__': 'simplex_method',
#               '__init__': <function simplex_method.SimplexMethod.__init__(self, materials: list, reserve: list, profit: list)>,
#               'recount_deltas': <function simplex_method.SimplexMethod.recount_deltas(self)>,
#               'permissive_column': <function simplex_method.SimplexMethod.permissive_column(self)>,
#               'permissive_row': <function simplex_method.SimplexMethod.permissive_row(self, min_profit_ind: int)>,
#               'recount_table': <function simplex_method.SimplexMethod.recount_table(self, row_index: int, col_index: int)>,
#               'target_function': <function simplex_method.SimplexMethod.target_function(self)>,
#               'iteration': <function simplex_method.SimplexMethod.iteration(self)>,
#               'save_iteration': <function simplex_method.SimplexMethod.save_iteration(self)>,
#               'save_results': <function simplex_method.SimplexMethod.save_results(self)>,
#               'solve': <function simplex_method.SimplexMethod.solve(self)>,
#               '__dict__': <attribute '__dict__' of 'SimplexMethod' objects>,
#               '__weakref__': <attribute '__weakref__' of 'SimplexMethod' objects>,
#               '__doc__': None})
